# %%
import os, requests, json
from bs4 import BeautifulSoup
from urllib.parse import urlparse, urljoin
import csv
import pandas as pd

# %% [markdown]
# ## CommonCrawl Data

# %%
# For parsing URLs:
from urllib.parse import quote_plus
from bs4 import BeautifulSoup

# %%
# when missing, install trafilatura module for easy text extraction from web pages
# !pip install trafilatura

# %%
import trafilatura

# %%
def search_cc_index(url, index_name):
    """
    Search the Common Crawl Index for a given URL.

    This function queries the Common Crawl Index API to find records related to the specified URL. 
    It uses the index specified by `index_name` to retrieve the data and returns a list of JSON objects, 
    each representing a record from the index.

    Arguments:
        url (str): The URL to search for in the Common Crawl Index.
        index_name (str): The name of the Common Crawl Index to search (e.g., "CC-MAIN-2024-10").

    Returns:
        list: A list of JSON objects representing records found in the Common Crawl Index. 
              Returns None if the request fails or no records are found.

    Example:
        >>> search_cc_index("example.com", "CC-MAIN-2024-10")
        [{...}, {...}, ...]
    """
    encoded_url = quote_plus(url)
    index_url = f'http://index.commoncrawl.org/{index_name}-index?url={encoded_url}&output=json'
    response = requests.get(index_url)

    if response.status_code == 200:
        records = response.text.strip().split('\n')
        return [json.loads(record) for record in records]
    else:
        return None



def fetch_single_record(warc_record_filename, offset, length):
    """
    Fetch a single WARC record from Common Crawl.

    Arguments:
        record {dict} -- A dictionary containing the WARC record details.

    Returns:
        bytes or None -- The raw content of the response if found, otherwise None.
    """
    
    s3_url = f'https://data.commoncrawl.org/{warc_record_filename}'

    # Define the byte range for the request
    byte_range = f'bytes={offset}-{offset + length - 1}'

    # Send the HTTP GET request to the S3 URL with the specified byte range
    response = requests.get(
        s3_url,
        headers={'Range': byte_range},
        stream=True
    )

    if response.status_code == 206:
        # Use `stream=True` in the call to `requests.get()` to get a raw byte stream,
        # because it's gzip compressed data
        stream = ArchiveIterator(response.raw)
        for warc_record in stream:
            if warc_record.rec_type == 'response':
                return warc_record.content_stream().read()
    else:
        print(f"Failed to fetch data: {response.status_code}")
    
    return None


def append_df_row_to_pickle(row, pickle_file):
    """
    Append a row to a DataFrame stored in a pickle file.
    
    Arguments:
        row {pd.Series} -- The row to be appended to the DataFrame.
        pickle_file {str} -- The path to the pickle file where the DataFrame is stored.
    """
    # Check if the pickle file exists
    if os.path.exists(pickle_file):
        # Load the existing DataFrame from the pickle file
        df = pd.read_pickle(pickle_file)
    else:
        # If the file doesn't exist, create a new DataFrame
        df = pd.DataFrame(columns=row.index)

    # Append the new row to the DataFrame
    df = pd.concat([df, pd.DataFrame([row])], ignore_index=True)
    
    # Save the updated DataFrame back to the pickle file
    df.to_pickle(pickle_file)


def load_processed_indices(pickle_file):
    """
    Load processed indices from a pickle file to check previously processed records.

    Arguments:
        pickle_file {str} -- The path to the pickle file where the DataFrame is stored.
    
    Returns:
        Set of processed indices.
    """
    if os.path.exists(pickle_file):
        df = pd.read_pickle(pickle_file)
        # Assuming 'index' column is in the DataFrame and contains indices of processed records
        processed_indices = set(df['index'].unique())
        print(f"Loaded {len(processed_indices)} processed indices from {pickle_file}")
        return processed_indices
    else:
        print(f"No processed indices found. Pickle file '{pickle_file}' does not exist.")
        return set()

# %%
# load the list of URLs per country to search for in CC
# Country code: change here between 'NL' and 'UK'
cc_list = ['NL', 'UK', 'DE', 'FR']
''' when it works, 
    transform this code 
    into a for loop
    to loop through the cc_list
'''
url_list = pd.read_csv('./url_lists/'+cc_list[0]+'_urls.csv')[cc_list[0]+' domains'].values.tolist()

# %%
len(url_list)
# Out:
# 53

# %%
# Import json data from Aipfy scraping into 4 separate dataframes

df0=pd.read_json(gdrive_path+cc_list[0]+'_dataset_website-content-crawler.json')
# select only two columns for analysis: url and text
df0=df0[['url','text']]

df1=pd.read_json(gdrive_path+cc_list[1]+'_dataset_website-content-crawler.json')
# select only two columns for analysis: url and text
df1=df1[['url','text']]

df2=pd.read_json(gdrive_path+cc_list[2]+'_dataset_website-content-crawler.json')
# select only two columns for analysis: url and text
df2=df2[['url','text']]

df3=pd.read_json(gdrive_path+cc_list[3]+'_dataset_website-content-crawler.json')
# select only two columns for analysis: url and text
df3=df3[['url','text']]

df0.head()
# Out:
#   Cell In[5], line 5
#     df0=pd.read_json(gdrive_path+cc_list[0]+'_dataset_website-content-crawler.json')
#     ^
# IndentationError: expected an indented block

# %%
# create a mapping of dataframes which could be addressed in a loop
df_dict = {'0':df0, '1':df1, '2':df2, '3':df3}

# then, loop through the df_dict to update each dataframe
for k, v in df_dict.items():

# %% [markdown]
# List of all Common Crawl indexes since 2018:
# - **2024:** 'CC-MAIN-2024-51', 'CC-MAIN-2024-46', 'CC-MAIN-2024-42', 'CC-MAIN-2024-38', 'CC-MAIN-2024-33', 'CC-MAIN-2024-30', 'CC-MAIN-2024-26', 'CC-MAIN-2024-22', 'CC-MAIN-2024-18', 'CC-MAIN-2024-10'
# - **2023:** CC-MAIN-2023-50 // CC-MAIN-2023-40 // CC-MAIN-2023-23 // CC-MAIN-2023-14 // CC-MAIN-2023-06 //
# - **2022:** CC-MAIN-2022-49 // CC-MAIN-2022-40 // CC-MAIN-2022-33 // CC-MAIN-2022-27 // CC-MAIN-2022-21 // CC-MAIN-2022-05
# - **2021:** CC-MAIN-2021-49 // CC-MAIN-2021-43 // CC-MAIN-2021-39 // CC-MAIN-2021-31 // CC-MAIN-2021-25 // CC-MAIN-2021-21 // CC-MAIN-2021-17 // CC-MAIN-2021-10 // CC-MAIN-2021-04 //
# - **2020:** CC-MAIN-2020-50 // CC-MAIN-2020-45 // CC-MAIN-2020-40 // CC-MAIN-2020-34 // CC-MAIN-2020-29 // CC-MAIN-2020-24 // CC-MAIN-2020-16 // CC-MAIN-2020-10 // CC-MAIN-2020-05 //
# - **2019:** CC-MAIN-2019-51 // CC-MAIN-2019-47 // CC-MAIN-2019-43 // CC-MAIN-2019-39 // CC-MAIN-2019-35 // CC-MAIN-2019-30 // CC-MAIN-2019-26 // CC-MAIN-2019-22 // CC-MAIN-2019-18 // CC-MAIN-2019-13 // CC-MAIN-2019-09 // CC-MAIN-2019-04
# - **2018:** 'CC-MAIN-2018-51', 'CC-MAIN-2018-47', 'CC-MAIN-2018-43', 'CC-MAIN-2018-39', 'CC-MAIN-2018-34', 'CC-MAIN-2018-30', 'CC-MAIN-2018-26', 'CC-MAIN-2018-22', 'CC-MAIN-2018-17', 'CC-MAIN-2018-13', 'CC-MAIN-2018-09', 'CC-MAIN-2018-05'

# %% [markdown]
# ### Test one website data

# %%
# list of indexes https://commoncrawl.org/get-started
#indexes  = ['CC-MAIN-2024-46','CC-MAIN-2024-30','CC-MAIN-2024-26']
indexes = ['CC-MAIN-2024-51', 'CC-MAIN-2024-46', 'CC-MAIN-2024-42', 'CC-MAIN-2024-38', 'CC-MAIN-2024-33', 
           'CC-MAIN-2024-30', 'CC-MAIN-2024-26', 'CC-MAIN-2024-22', 'CC-MAIN-2024-18', 'CC-MAIN-2024-10']

record_dfs = []
target_url = url_list[33]
print("searching all records for ", target_url, " in indexes")

# Fetch each index and store into a dataframe
for index_name in indexes:
    print('Running: ', index_name)
    records = search_cc_index(target_url,index_name)
    record_df = pd.DataFrame(records)
    record_df['index_name'] = index_name
    record_dfs.append(record_df)

# Combine individual dataframes
all_records_df = pd.concat(record_dfs)
all_records_df = all_records_df.sort_values(by='index_name', ascending=False)
all_records_df = all_records_df.reset_index()

# Create columns where to store data later
all_records_df['success_status'] = 'not processed'
all_records_df['html'] = ''
# Out:
# searching all records for  https://www.middachten.nl  in indexes
# Running:  CC-MAIN-2024-51
# Running:  CC-MAIN-2024-46
# Running:  CC-MAIN-2024-42
# Running:  CC-MAIN-2024-38
# Running:  CC-MAIN-2024-33
# Running:  CC-MAIN-2024-30
# Running:  CC-MAIN-2024-26
# Running:  CC-MAIN-2024-22
# Running:  CC-MAIN-2024-18
# Running:  CC-MAIN-2024-10

# %%
# safeguareds
# If pickle file exists, check for processed items
pickle_file = 'commcrawl_indeed.pkl'
processed_indices = load_processed_indices(pickle_file)
#if processed_indices:
#    # Remove processed items
#    df = df[~df['index'].isin(processed_indices)]

# Create storage for later
successful = set()
results = {}

# Keep track of each row processed
i = 0 
perc = 0
n_records = len(all_records_df)
print(f"Found {n_records} records")
# Out:
# No processed indices found. Pickle file 'commcrawl_indeed.pkl' does not exist.
# Found 15 records

# %%
from warcio.archiveiterator import ArchiveIterator

# Reset index to help with looping
all_records_df.reset_index(drop=True,inplace=True)


for i in range(len(all_records_df)):
    record_url = all_records_df.loc[i, 'url']

    # Fetch only URLs that were not processed
    # If it was already processed, skip URL 
    # (Helps speeding if you only need one version of the HTML, not its history)
    if not record_url in successful:
        length = int(all_records_df.loc[i, 'length'])
        offset = int(all_records_df.loc[i, 'offset'])
        warc_record_filename = all_records_df.loc[i, 'filename']
        result = fetch_single_record(warc_record_filename, offset, length)
        
        if not result:
            all_records_df.loc[i,'success_status'] = 'invalid warc'
        else:
            all_records_df.loc[i,'success_status'] = 'success'
            all_records_df.loc[i,'html'] = result
    else: 
        all_records_df.loc[i,'success_status'] = 'previously processed'

    # Add to pickle file
    append_df_row_to_pickle(all_records_df.loc[i, :], pickle_file)

# %%
commoncrawl_data = pd.read_pickle(pickle_file)
commoncrawl_data[
    ['url','filename','index_name','success_status','html']
    ]
# Out:
#                            url  \
# 0    https://www.middachten.nl
# 1   https://www.middachten.nl/
# 2    https://www.middachten.nl
# 3   https://www.middachten.nl/
# 4    https://www.middachten.nl
# 5   https://www.middachten.nl/
# 6    https://www.middachten.nl
# 7   https://www.middachten.nl/
# 8   https://www.middachten.nl/
# 9    https://www.middachten.nl
# 10  https://www.middachten.nl/
# 11   http://www.middachten.nl/
# 12  https://www.middachten.nl/
# 13   https://www.middachten.nl
# 14  https://www.middachten.nl/
# 15   https://www.middachten.nl
# 16  https://www.middachten.nl/
# 17   https://www.middachten.nl
# 18  https://www.middachten.nl/
# 19   https://www.middachten.nl
# 20  https://www.middachten.nl/
# 21   https://www.middachten.nl
# 22  https://www.middachten.nl/
# 23  https://www.middachten.nl/
# 24   https://www.middachten.nl
# 25  https://www.middachten.nl/
# 26   http://www.middachten.nl/
# 27  https://www.middachten.nl/
# 28   https://www.middachten.nl
# 29  https://www.middachten.nl/
# 30   https://www.middachten.nl
# 31  https://www.middachten.nl/
# 32   https://www.middachten.nl
# 33  https://www.middachten.nl/
# 34   https://www.middachten.nl
# 35  https://www.middachten.nl/
# 36   https://www.middachten.nl
# 37  https://www.middachten.nl/
# 38  https://www.middachten.nl/
# 39   https://www.middachten.nl
# 40  https://www.middachten.nl/
# 41   http://www.middachten.nl/
# 42  https://www.middachten.nl/
# 43   https://www.middachten.nl
# 44  https://www.middachten.nl/
#
#                                              filename       index_name  \
# 0   crawl-data/CC-MAIN-2024-51/segments/1733066127...  CC-MAIN-2024-51
# 1   crawl-data/CC-MAIN-2024-51/segments/1733066127...  CC-MAIN-2024-51
# 2   crawl-data/CC-MAIN-2024-46/segments/1730477395...  CC-MAIN-2024-46
# 3   crawl-data/CC-MAIN-2024-46/segments/1730477395...  CC-MAIN-2024-46
# 4   crawl-data/CC-MAIN-2024-42/segments/1727944253...  CC-MAIN-2024-42
# 5   crawl-data/CC-MAIN-2024-42/segments/1727944253...  CC-MAIN-2024-42
# 6   crawl-data/CC-MAIN-2024-38/segments/1725700651...  CC-MAIN-2024-38
# 7   crawl-data/CC-MAIN-2024-38/segments/1725700651...  CC-MAIN-2024-38
# 8   crawl-data/CC-MAIN-2024-38/segments/1725700651...  CC-MAIN-2024-38
# 9   crawl-data/CC-MAIN-2024-26/segments/1718198861...  CC-MAIN-2024-26
# 10  crawl-data/CC-MAIN-2024-22/segments/1715971059...  CC-MAIN-2024-22
# 11  crawl-data/CC-MAIN-2024-22/segments/1715971059...  CC-MAIN-2024-22
# 12  crawl-data/CC-MAIN-2024-22/segments/1715971059...  CC-MAIN-2024-22
# 13  crawl-data/CC-MAIN-2024-22/segments/1715971059...  CC-MAIN-2024-22
# 14  crawl-data/CC-MAIN-2024-18/segments/1712296817...  CC-MAIN-2024-18
# 15  crawl-data/CC-MAIN-2024-51/segments/1733066127...  CC-MAIN-2024-51
# 16  crawl-data/CC-MAIN-2024-51/segments/1733066127...  CC-MAIN-2024-51
# 17  crawl-data/CC-MAIN-2024-46/segments/1730477395...  CC-MAIN-2024-46
# 18  crawl-data/CC-MAIN-2024-46/segments/1730477395...  CC-MAIN-2024-46
# 19  crawl-data/CC-MAIN-2024-42/segments/1727944253...  CC-MAIN-2024-42
# 20  crawl-data/CC-MAIN-2024-42/segments/1727944253...  CC-MAIN-2024-42
# 21  crawl-data/CC-MAIN-2024-38/segments/1725700651...  CC-MAIN-2024-38
# 22  crawl-data/CC-MAIN-2024-38/segments/1725700651...  CC-MAIN-2024-38
# 23  crawl-data/CC-MAIN-2024-38/segments/1725700651...  CC-MAIN-2024-38
# 24  crawl-data/CC-MAIN-2024-26/segments/1718198861...  CC-MAIN-2024-26
# 25  crawl-data/CC-MAIN-2024-22/segments/1715971059...  CC-MAIN-2024-22
# 26  crawl-data/CC-MAIN-2024-22/segments/1715971059...  CC-MAIN-2024-22
# 27  crawl-data/CC-MAIN-2024-22/segments/1715971059...  CC-MAIN-2024-22
# 28  crawl-data/CC-MAIN-2024-22/segments/1715971059...  CC-MAIN-2024-22
# 29  crawl-data/CC-MAIN-2024-18/segments/1712296817...  CC-MAIN-2024-18
# 30  crawl-data/CC-MAIN-2024-51/segments/1733066127...  CC-MAIN-2024-51
# 31  crawl-data/CC-MAIN-2024-51/segments/1733066127...  CC-MAIN-2024-51
# 32  crawl-data/CC-MAIN-2024-46/segments/1730477395...  CC-MAIN-2024-46
# 33  crawl-data/CC-MAIN-2024-46/segments/1730477395...  CC-MAIN-2024-46
# 34  crawl-data/CC-MAIN-2024-42/segments/1727944253...  CC-MAIN-2024-42
# 35  crawl-data/CC-MAIN-2024-42/segments/1727944253...  CC-MAIN-2024-42
# 36  crawl-data/CC-MAIN-2024-38/segments/1725700651...  CC-MAIN-2024-38
# 37  crawl-data/CC-MAIN-2024-38/segments/1725700651...  CC-MAIN-2024-38
# 38  crawl-data/CC-MAIN-2024-38/segments/1725700651...  CC-MAIN-2024-38
# 39  crawl-data/CC-MAIN-2024-26/segments/1718198861...  CC-MAIN-2024-26
# 40  crawl-data/CC-MAIN-2024-22/segments/1715971059...  CC-MAIN-2024-22
# 41  crawl-data/CC-MAIN-2024-22/segments/1715971059...  CC-MAIN-2024-22
# 42  crawl-data/CC-MAIN-2024-22/segments/1715971059...  CC-MAIN-2024-22
# 43  crawl-data/CC-MAIN-2024-22/segments/1715971059...  CC-MAIN-2024-22
# 44  crawl-data/CC-MAIN-2024-18/segments/1712296817...  CC-MAIN-2024-18
#
#    success_status                                               html
# 0         success  b'<!DOCTYPE html>\n<html lang="nl-NL" >\n\n<he...
# 1         success  b'<!DOCTYPE html>\n<html lang="nl-NL" >\n\n<he...
# 2         success  b'<!DOCTYPE html><html\nlang=nl-NL ><head><sty...
# 3         success  b'<!DOCTYPE html><html\nlang=nl-NL ><head><sty...
# 4         success  b'<!DOCTYPE html><html\nlang=nl-NL ><head><sty...
# 5         success  b'<!DOCTYPE html><html\nlang=nl-NL ><head><sty...
# 6         success  b'<!DOCTYPE html><html\nlang=nl-NL ><head><sty...
# 7         success  b'<!DOCTYPE html><html\nlang=nl-NL ><head><sty...
# 8         success  b'<!DOCTYPE html><html\nlang=nl-NL ><head><sty...
# 9         success  b'<!DOCTYPE html>\n<html lang="nl-NL" >\n\n<he...
# 10        success  b'<!DOCTYPE html>\n<html lang="nl-NL" >\n\n<he...
# 11        success  b'<!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0...
# 12        success  b'<!DOCTYPE html>\n<html lang="nl-NL" >\n\n<he...
# 13        success  b'<!DOCTYPE html>\n<html lang="nl-NL" >\n\n<he...
# 14        success  b'<!DOCTYPE html>\n<html lang="nl-NL" >\n<head...
# 15        success  b'<!DOCTYPE html>\n<html lang="nl-NL" >\n\n<he...
# 16        success  b'<!DOCTYPE html>\n<html lang="nl-NL" >\n\n<he...
# 17        success  b'<!DOCTYPE html><html\nlang=nl-NL ><head><sty...
# 18        success  b'<!DOCTYPE html><html\nlang=nl-NL ><head><sty...
# 19        success  b'<!DOCTYPE html><html\nlang=nl-NL ><head><sty...
# 20        success  b'<!DOCTYPE html><html\nlang=nl-NL ><head><sty...
# 21        success  b'<!DOCTYPE html><html\nlang=nl-NL ><head><sty...
# 22        success  b'<!DOCTYPE html><html\nlang=nl-NL ><head><sty...
# 23        success  b'<!DOCTYPE html><html\nlang=nl-NL ><head><sty...
# 24        success  b'<!DOCTYPE html>\n<html lang="nl-NL" >\n\n<he...
# 25        success  b'<!DOCTYPE html>\n<html lang="nl-NL" >\n\n<he...
# 26        success  b'<!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0...
# 27        success  b'<!DOCTYPE html>\n<html lang="nl-NL" >\n\n<he...
# 28        success  b'<!DOCTYPE html>\n<html lang="nl-NL" >\n\n<he...
# 29        success  b'<!DOCTYPE html>\n<html lang="nl-NL" >\n<head...
# 30        success  b'<!DOCTYPE html>\n<html lang="nl-NL" >\n\n<he...
# 31        success  b'<!DOCTYPE html>\n<html lang="nl-NL" >\n\n<he...
# 32        success  b'<!DOCTYPE html><html\nlang=nl-NL ><head><sty...
# 33        success  b'<!DOCTYPE html><html\nlang=nl-NL ><head><sty...
# 34        success  b'<!DOCTYPE html><html\nlang=nl-NL ><head><sty...
# 35        success  b'<!DOCTYPE html><html\nlang=nl-NL ><head><sty...
# 36        success  b'<!DOCTYPE html><html\nlang=nl-NL ><head><sty...
# 37        success  b'<!DOCTYPE html><html\nlang=nl-NL ><head><sty...
# 38        success  b'<!DOCTYPE html><html\nlang=nl-NL ><head><sty...
# 39        success  b'<!DOCTYPE html>\n<html lang="nl-NL" >\n\n<he...
# 40        success  b'<!DOCTYPE html>\n<html lang="nl-NL" >\n\n<he...
# 41        success  b'<!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0...
# 42        success  b'<!DOCTYPE html>\n<html lang="nl-NL" >\n\n<he...
# 43        success  b'<!DOCTYPE html>\n<html lang="nl-NL" >\n\n<he...
# 44        success  b'<!DOCTYPE html>\n<html lang="nl-NL" >\n<head...

# %%
commoncrawl_data.filename.unique()
# Out:
# array(['crawl-data/CC-MAIN-2024-51/segments/1733066127466.39/warc/CC-MAIN-20241202094452-20241202124452-00418.warc.gz',
#        'crawl-data/CC-MAIN-2024-51/segments/1733066127466.39/warc/CC-MAIN-20241202094452-20241202124452-00165.warc.gz',
#        'crawl-data/CC-MAIN-2024-46/segments/1730477395538.95/warc/CC-MAIN-20241114194152-20241114224152-00418.warc.gz',
#        'crawl-data/CC-MAIN-2024-46/segments/1730477395538.95/warc/CC-MAIN-20241114194152-20241114224152-00165.warc.gz',
#        'crawl-data/CC-MAIN-2024-42/segments/1727944253701.40/warc/CC-MAIN-20241010190240-20241010220240-00418.warc.gz',
#        'crawl-data/CC-MAIN-2024-42/segments/1727944253701.40/warc/CC-MAIN-20241010190240-20241010220240-00165.warc.gz',
#        'crawl-data/CC-MAIN-2024-38/segments/1725700651303.70/warc/CC-MAIN-20240910161250-20240910191250-00418.warc.gz',
#        'crawl-data/CC-MAIN-2024-38/segments/1725700651303.70/warc/CC-MAIN-20240910161250-20240910191250-00165.warc.gz',
#        'crawl-data/CC-MAIN-2024-38/segments/1725700651506.7/warc/CC-MAIN-20240913002450-20240913032450-00165.warc.gz',
#        'crawl-data/CC-MAIN-2024-26/segments/1718198861584.65/warc/CC-MAIN-20240615062230-20240615092230-00418.warc.gz',
#        'crawl-data/CC-MAIN-2024-22/segments/1715971059221.97/warc/CC-MAIN-20240529072748-20240529102748-00165.warc.gz',
#        'crawl-data/CC-MAIN-2024-22/segments/1715971059384.83/crawldiagnostics/CC-MAIN-20240529165728-20240529195728-00514.warc.gz',
#        'crawl-data/CC-MAIN-2024-22/segments/1715971059384.83/warc/CC-MAIN-20240529165728-20240529195728-00165.warc.gz',
#        'crawl-data/CC-MAIN-2024-22/segments/1715971059384.83/warc/CC-MAIN-20240529165728-20240529195728-00418.warc.gz',
#        'crawl-data/CC-MAIN-2024-18/segments/1712296817103.42/warc/CC-MAIN-20240416155952-20240416185952-00165.warc.gz'],
#       dtype=object)

# %%
webpage = commoncrawl_data.html[1]
trafilatura.extract(webpage)
# Out:
# "Welkom op Middachten\nAl 800 jaar een gastvrij landgoed in bedrijf.\nKasteel Middachten opent ook dit jaar haar deuren voor een onvergetelijke kerstervaring voor jong en oud. Laat je meevoeren in een betoverend winterwonderland vol kerstbomen, fonkelende lichtjes, schitterende decoraties en nog veel meer! Lees verder…\nDeze website maakt gebruik van cookies. Door op 'Accepteren' te klikken, ga je akkoord met het gebruik van alle cookies op deze website."

# %%
def extract_text_from_html(html):
  try:
    text = trafilatura.extract(html)
    return text
  except:
    return None

commoncrawl_data['text'] = commoncrawl_data['html'].apply(extract_text_from_html)

# %%
commoncrawl_data.text[0]
# Out:
# "Welkom op Middachten\nAl 800 jaar een gastvrij landgoed in bedrijf.\nKasteel Middachten opent ook dit jaar haar deuren voor een onvergetelijke kerstervaring voor jong en oud. Laat je meevoeren in een betoverend winterwonderland vol kerstbomen, fonkelende lichtjes, schitterende decoraties en nog veel meer! Lees verder…\nDeze website maakt gebruik van cookies. Door op 'Accepteren' te klikken, ga je akkoord met het gebruik van alle cookies op deze website."

# %%
commoncrawl_data.text.unique()
# Out:
# array(["Welkom op Middachten\nAl 800 jaar een gastvrij landgoed in bedrijf.\nKasteel Middachten opent ook dit jaar haar deuren voor een onvergetelijke kerstervaring voor jong en oud. Laat je meevoeren in een betoverend winterwonderland vol kerstbomen, fonkelende lichtjes, schitterende decoraties en nog veel meer! Lees verder…\nDeze website maakt gebruik van cookies. Door op 'Accepteren' te klikken, ga je akkoord met het gebruik van alle cookies op deze website.",
#        "Deze website maakt gebruik van cookies. Door op 'Accepteren' te klikken, ga je akkoord met het gebruik van alle cookies op deze website.",
#        "Welkom op Middachten\nAl 800 jaar een gastvrij landgoed in bedrijf.\nBezoek ons prachtige kasteel, de schitterende tuinen en de expositie ‘In Volle Vaart’ tijdens Open Monumentendag in het 2de weekend van september!\nDeze website maakt gebruik van cookies. Door op 'Accepteren' te klikken, ga je akkoord met het gebruik van alle cookies op deze website.",
#        "Welkom op Middachten\nAl 800 jaar een gastvrij landgoed in bedrijf.\nKom naar de Dag van het Kasteel op maandag 20 mei, 2de Pinksterdag.\nKasteel geopend van 12.30-16.30 uur.\nDeze website maakt gebruik van cookies. Door op 'Accepteren' te klikken, ga je akkoord met het gebruik van alle cookies op deze website.",
#        'Moved Permanently\nThe document has moved\nhere\n.',
#        "Welkom op Middachten\nAl 800 jaar een gastvrij landgoed in bedrijf.\nTijdens de jaarlijkse ‘Dag van het Kasteel’ op Tweede Pinksterdag maandag 29 mei zijn er vanaf 12.30 u speciale rondleidingen in het kasteel.\nDeze website maakt gebruik van cookies. Door op 'Accepteren' te klikken, ga je akkoord met het gebruik van alle cookies op deze website."],
#       dtype=object)

# %%
document = commoncrawl_data.text.tolist()

file_path = 'midd' + '.txt'

with open(file_path, 'w') as f:
    for text in document:
      f.write(text + '\n')

# %% [markdown]
# ## 2024 Data

# %%
# list of indexes https://commoncrawl.org/get-started
#indexes  = ['CC-MAIN-2024-46','CC-MAIN-2024-30','CC-MAIN-2024-26']
indexes = ['CC-MAIN-2024-51', 'CC-MAIN-2024-46', 'CC-MAIN-2024-42', 'CC-MAIN-2024-38', 'CC-MAIN-2024-33', 'CC-MAIN-2024-30', 'CC-MAIN-2024-26', 'CC-MAIN-2024-22', 'CC-MAIN-2024-18', 'CC-MAIN-2024-10']

record_dfs = []

# Fetch each index and store into a dataframe
for index_name in indexes:
    print('Running: ', index_name)
    for i in range((len(url_list)-1)):
        records = search_cc_index(url_list[i],index_name)
        record_df = pd.DataFrame(records)
        record_df['index_name'] = index_name
        record_dfs.append(record_df)

# Combine individual dataframes
all_records_df = pd.concat(record_dfs)
all_records_df = all_records_df.sort_values(by='index_name', ascending=False)
all_records_df = all_records_df.reset_index()

# Create columns where to store data later
all_records_df['success_status'] = 'not processed'
all_records_df['html'] = ''
# Out:
# Running:  CC-MAIN-2024-51
# Running:  CC-MAIN-2024-46
# Running:  CC-MAIN-2024-42
# Running:  CC-MAIN-2024-38
# Running:  CC-MAIN-2024-33
# Running:  CC-MAIN-2024-30
# Running:  CC-MAIN-2024-26
# Running:  CC-MAIN-2024-22
# Running:  CC-MAIN-2024-18
# Running:  CC-MAIN-2024-10

# %%
# SKIP
# or run if needed
all_records_df.to_csv('all_records_df.csv', index=False)

# %%
df = all_records_df

# %%
# safeguareds
# If pickle file exists, check for processed items
pickle_file = 'commcrawl_indeed.pkl'
processed_indices = load_processed_indices(pickle_file)
#if processed_indices:
#    # Remove processed items
#    df = df[~df['index'].isin(processed_indices)]

# Create storage for later
successful = set()
results = {}

# Keep track of each row processed
i = 0 
perc = 0
n_records = len(df)
print(f"Found {n_records} records")
mod = int(n_records * 0.01)
# Out:
# No processed indices found. Pickle file 'commcrawl_indeed.pkl' does not exist.
# Found 405 records

# %%
from warcio.archiveiterator import ArchiveIterator

# Reset index to help with looping
df.reset_index(drop=True,inplace=True)


for i in range(len(df)):
    # Print every 1% process
    if i % mod == 0: 
        print(f'{i} of {n_records}: {perc}%')
        perc += 1

    record_url = df.loc[i, 'url']

    # Fetch only URLs that were not processed
    # If it was already processed, skip URL 
    # (Helps speeding if you only need one version of the HTML, not its history)
    if not record_url in successful:
        length = int(df.loc[i, 'length'])
        offset = int(df.loc[i, 'offset'])
        warc_record_filename = df.loc[i, 'filename']
        result = fetch_single_record(warc_record_filename, offset, length)
        
        if not result:
            df.loc[i,'success_status'] = 'invalid warc'
        else:
            df.loc[i,'success_status'] = 'success'
            df.loc[i,'html'] = result
    else: 
        df.loc[i,'success_status'] = 'previously processed'

    # Add to pickle file
    append_df_row_to_pickle(df.loc[i, :], pickle_file)
# Out:
# 0 of 405: 0%
# 4 of 405: 1%
# 8 of 405: 2%
# 12 of 405: 3%
# 16 of 405: 4%
# 20 of 405: 5%
# 24 of 405: 6%
# 28 of 405: 7%
# 32 of 405: 8%
# 36 of 405: 9%
# 40 of 405: 10%
# 44 of 405: 11%
# 48 of 405: 12%
# 52 of 405: 13%
# 56 of 405: 14%
# 60 of 405: 15%
# 64 of 405: 16%
# 68 of 405: 17%
# 72 of 405: 18%
# 76 of 405: 19%
# 80 of 405: 20%
# 84 of 405: 21%
# 88 of 405: 22%
# 92 of 405: 23%
# 96 of 405: 24%
# 100 of 405: 25%
# 104 of 405: 26%
# 108 of 405: 27%
# 112 of 405: 28%
# 116 of 405: 29%
# 120 of 405: 30%
# 124 of 405: 31%
# 128 of 405: 32%
# 132 of 405: 33%
# 136 of 405: 34%
# 140 of 405: 35%
# 144 of 405: 36%
# 148 of 405: 37%
# 152 of 405: 38%
# 156 of 405: 39%
# 160 of 405: 40%
# 164 of 405: 41%
# 168 of 405: 42%
# 172 of 405: 43%
# 176 of 405: 44%
# 180 of 405: 45%
# 184 of 405: 46%
# 188 of 405: 47%
# 192 of 405: 48%
# 196 of 405: 49%
# 200 of 405: 50%
# 204 of 405: 51%
# 208 of 405: 52%
# 212 of 405: 53%
# 216 of 405: 54%
# 220 of 405: 55%
# 224 of 405: 56%
# 228 of 405: 57%
# 232 of 405: 58%
# 236 of 405: 59%
# 240 of 405: 60%
# 244 of 405: 61%
# 248 of 405: 62%
# 252 of 405: 63%
# 256 of 405: 64%
# 260 of 405: 65%
# 264 of 405: 66%
# 268 of 405: 67%
# 272 of 405: 68%
# 276 of 405: 69%
# 280 of 405: 70%
# 284 of 405: 71%
# 288 of 405: 72%
# 292 of 405: 73%
# 296 of 405: 74%
# 300 of 405: 75%
# 304 of 405: 76%
# 308 of 405: 77%
# 312 of 405: 78%
# 316 of 405: 79%
# 320 of 405: 80%
# 324 of 405: 81%
# 328 of 405: 82%
# 332 of 405: 83%
# 336 of 405: 84%
# 340 of 405: 85%
# 344 of 405: 86%
# 348 of 405: 87%
# 352 of 405: 88%
# 356 of 405: 89%
# 360 of 405: 90%
# 364 of 405: 91%
# 368 of 405: 92%
# 372 of 405: 93%
# 376 of 405: 94%
# 380 of 405: 95%
# 384 of 405: 96%
# 388 of 405: 97%
# 392 of 405: 98%
# 396 of 405: 99%
# 400 of 405: 100%
# 404 of 405: 101%

# %%
commoncrawl_data = pd.read_pickle(pickle_file)
commoncrawl_data[
    ['url','filename','index_name','success_status','html']
    ].head()
# Out:
#                                     url  \
# 0              https://www.artland.top/
# 1              http://www.sypesteyn.nl/
# 2  https://www.kasteeltuinassumburg.nl/
# 3         https://ruinevanbrederode.nl/
# 4         https://ruinevanbrederode.nl/
#
#                                             filename       index_name  \
# 0  crawl-data/CC-MAIN-2024-51/segments/1733066127...  CC-MAIN-2024-51
# 1  crawl-data/CC-MAIN-2024-51/segments/1733066449...  CC-MAIN-2024-51
# 2  crawl-data/CC-MAIN-2024-51/segments/1733066035...  CC-MAIN-2024-51
# 3  crawl-data/CC-MAIN-2024-51/segments/1733066329...  CC-MAIN-2024-51
# 4  crawl-data/CC-MAIN-2024-51/segments/1733066047...  CC-MAIN-2024-51
#
#   success_status                                               html
# 0        success  b'<!DOCTYPE html>\n<html lang="nl">\n    <head...
# 1        success  b'\n<!doctype html>\n<html lang="en">\n<head>\...
# 2        success  b'<!doctype html>\n<html lang="nl-NL" prefix="...
# 3        success  b'<!DOCTYPE html>\n<html class="avada-html-lay...
# 4        success  b'<!DOCTYPE html>\n<html class="avada-html-lay...

# %%
m1 = commoncrawl_data[~commoncrawl_data[['url']].duplicated()]

# %%
m1
# Out:
#     index       index_name                     urlkey       timestamp  \
# 0       0  CC-MAIN-2024-51              top,artland)/  20241202145148
# 1       0  CC-MAIN-2024-51             nl,sypesteyn)/  20241208192644
# 2       0  CC-MAIN-2024-51  nl,kasteeltuinassumburg)/  20241201181716
# 3       0  CC-MAIN-2024-51     nl,ruinevanbrederode)/  20241205031650
# 5       0  CC-MAIN-2024-51     nl,kasteelvalkenburg)/  20241214111044
# ..    ...              ...                        ...             ...
# 388     1  CC-MAIN-2024-10          nl,kasteelheeze)/  20240303094635
# 391     2  CC-MAIN-2024-10         nl,museummartena)/  20240226064857
# 393     0  CC-MAIN-2024-10            nl,slotzuylen)/  20240301205802
# 402     0  CC-MAIN-2024-10         nl,museummartena)/  20240226064857
# 403     1  CC-MAIN-2024-10         nl,museummartena)/  20240226064857
#
#                                       url       mime mime-detected status  \
# 0                https://www.artland.top/  text/html     text/html    200
# 1                http://www.sypesteyn.nl/  text/html     text/html    200
# 2    https://www.kasteeltuinassumburg.nl/  text/html     text/html    200
# 3           https://ruinevanbrederode.nl/  text/html     text/html    200
# 5       https://www.kasteelvalkenburg.nl/  text/html     text/html    200
# ..                                    ...        ...           ...    ...
# 388           http://www.kasteelheeze.nl/  text/html     text/html    301
# 391             https://museummartena.nl/  text/html     text/html    301
# 393                 http://slotzuylen.nl/  text/html     text/html    301
# 402              http://museummartena.nl/  text/html     text/html    301
# 403          http://www.museummartena.nl/  text/html     text/html    301
#
#                                digest length     offset  \
# 0    NUVW44YE5H2XIA7V2WXICTC6HDTOUXHO   8415  614889314
# 1    HYMVK23MO7EFTRVES2TUSQAPB6GRGZIS   1188   51684207
# 2    J3UBTSYVKOUR6NRLDODRYHL4DZYFDIT3  59300  791873947
# 3    536Y6Q2N3GNVKSCC4Y3APGH4JQPREPAQ  12932  460813328
# 5    UZEMGNM6TRMNMPPWRJGXKR3NJ7XJQUB3  31023  747772457
# ..                                ...    ...        ...
# 388  VCGGKYHEN445ZIZ2DO54OTBRT2E237RK    567    2357294
# 391  3I42H3S6NNFQ2MSVX7XZKYAYSCX5QBYJ    723   16640626
# 393  LGGT76I5HYSS6HQT36GPANELE4H7FWR7    569    2133700
# 402  HLNR6AWVWYCU3YAENY3HYHLIPNWN66X7    560    1358492
# 403  HLNR6AWVWYCU3YAENY3HYHLIPNWN66X7    565    3577637
#
#                                               filename languages encoding  \
# 0    crawl-data/CC-MAIN-2024-51/segments/1733066127...   nld,eng    UTF-8
# 1    crawl-data/CC-MAIN-2024-51/segments/1733066449...       eng    UTF-8
# 2    crawl-data/CC-MAIN-2024-51/segments/1733066035...       nld    UTF-8
# 3    crawl-data/CC-MAIN-2024-51/segments/1733066329...       nld    UTF-8
# 5    crawl-data/CC-MAIN-2024-51/segments/1733066124...   nld,eng    UTF-8
# ..                                                 ...       ...      ...
# 388  crawl-data/CC-MAIN-2024-10/segments/1707947476...       NaN      NaN
# 391  crawl-data/CC-MAIN-2024-10/segments/1707947474...       NaN      NaN
# 393  crawl-data/CC-MAIN-2024-10/segments/1707947475...       NaN      NaN
# 402  crawl-data/CC-MAIN-2024-10/segments/1707947474...       NaN      NaN
# 403  crawl-data/CC-MAIN-2024-10/segments/1707947474...       NaN      NaN
#
#                           redirect success_status  \
# 0                              NaN        success
# 1                              NaN        success
# 2                              NaN        success
# 3                              NaN        success
# 5                              NaN        success
# ..                             ...            ...
# 388   https://www.kasteelheeze.nl/        success
# 391   http://www.museummartena.nl/   invalid warc
# 393         https://slotzuylen.nl/        success
# 402      https://museummartena.nl/        success
# 403  https://www.museummartena.nl/        success
#
#                                                   html
# 0    b'<!DOCTYPE html>\n<html lang="nl">\n    <head...
# 1    b'\n<!doctype html>\n<html lang="en">\n<head>\...
# 2    b'<!doctype html>\n<html lang="nl-NL" prefix="...
# 3    b'<!DOCTYPE html>\n<html class="avada-html-lay...
# 5    b'<!doctype html>\n<html lang="nl-NL">\n<head>...
# ..                                                 ...
# 388  b'<html>\r\n<head><title>301 Moved Permanently...
# 391
# 393  b'<html>\r\n<head><title>301 Moved Permanently...
# 402  b'<html>\r\n<head><title>301 Moved Permanently...
# 403  b'<html>\r\n<head><title>301 Moved Permanently...
#
# [128 rows x 17 columns]

# %%
webpage = commoncrawl_data.html[0]
trafilatura.extract(webpage)
# Out:
# 'Artland Kasteel Strijthagen, Landgraaf\nArtland is sinds 2016 een internationaal kunstcentrum gelegen in complex Strijthagen. In de Hoeve van Strijthagen worden exposities en muziek evenementen georganiseerd, is een galerie met oude, moderne en hedendaagse beeldende kunst en een open atelier. Er vinden workshops en rondleidingen plaats. Rondom het complex is een beeldschoon vijverpark met het Beeldenpark.\nVolg Artland op Instagram @kasteelstrijthagen en @artland.to.do\n© ArtLand.top. All rights reserved. Kasteel Strijthagen. Strijthagen. Rouenhof 17-21, Landgraaf, Limburg. Nederland. Sitemap.'

# %% [markdown]
# ## 2018 Data

# %%
indexes_2018 = ['CC-MAIN-2018-51', 'CC-MAIN-2018-47', 'CC-MAIN-2018-43', 'CC-MAIN-2018-39', 'CC-MAIN-2018-34', 'CC-MAIN-2018-30', 'CC-MAIN-2018-26', 'CC-MAIN-2018-22', 'CC-MAIN-2018-17', 'CC-MAIN-2018-13', 'CC-MAIN-2018-09', 'CC-MAIN-2018-05']

record_dfs = []

# Fetch each index and store into a dataframe
for index_name in indexes_2018:
    print('Running: ', index_name)
    for i in range((len(url_list)-1)):
        records = search_cc_index(url_list[i],index_name)
        record_df = pd.DataFrame(records)
        record_df['index_name'] = index_name
        record_dfs.append(record_df)

# Combine individual dataframes
all_records_df = pd.concat(record_dfs)
all_records_df = all_records_df.sort_values(by='index_name', ascending=False)
all_records_df = all_records_df.reset_index()

# Create columns where to store data later
all_records_df['success_status'] = 'not processed'
all_records_df['html'] = ''
